# %%
import pymysql
import pandas as pd

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Create connections

# %%
host = '10.151.56.164'
port = 3306
user = 'uapowerbi'
password = 'pbi#2o20'
database = 'dwao'

# Connect to the MySQL database
conn_dwao = pymysql.connect(
    host=host,
    port=port,
    user=user,
    password=password,
    database=database,
)

#################################################################

#host = '10.151.56.164' -> same
#port = 3306 -> same
#user = 'uapowerbi' -> same
#password = 'pbi#2o20' -> same
database = 'staging_ao'

# Connect to the MySQL database
conn_staging = pymysql.connect(
    host=host,
    port=port,
    user=user,
    password=password,
    database=database
)

# %% [markdown]
# # Query

# %%
query = """
SELECT *
FROM dim_contaservico_dth_v2
LIMIT 100
"""
dim_contaservico_dth_v2 = pd.read_sql(query, conn_dwao)
# Out:
# /var/folders/3d/dh5fxyvd55sbf5r8pv3bfclw0000gq/T/ipykernel_29943/1002394191.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dim_contaservico_dth_v2 = pd.read_sql(query, conn_dwao)

# %%
dim_contaservico_dth_v2
# Out:
#     iddim_contaservico_dth  idcontaservico codigo_contaservico  \
# 0                        1              -1                   0
# 1                  2377450              54        100000540101
# 2                  2377451         1724111        100000540201
# 3                  2377452             424        100004140101
# 4                  2377453           74830        110128790101
# ..                     ...             ...                 ...
# 95                 2377544          102564        110292260301
# 96                 2377545          104071        110380410101
# 97                 2377546          104207        110381500101
# 98                 2377547          113214        110458060101
# 99                 2377548          114777        110471430101
#
#     iddim_data_criacao  iddim_tipocontaservico  iddim_conta  iddim_geografia  \
# 0                    0                       1          NaN              NaN
# ...
